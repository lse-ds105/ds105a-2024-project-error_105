# %%
from sqlalchemy import create_engine, text

# Define the database connection URL
DATABASE_URL = "sqlite:///../Data/main.db"  # Replace with your actual file path

# Create an SQLAlchemy engine
engine = create_engine(DATABASE_URL)

pd.set_option('display.max_rows', None)  # Display all rows in the dataframe
pd.set_option('display.max_colwidth', None)  # Show the full content of the descriptions

# Query the ice_pokemon table
ice_df = pd.read_sql_query("SELECT * FROM ice_pokemon", engine)

# Print the current 'pokemon_description' column
print(ice_df['pokemon_description'])

descriptions_ice = [
    "Glastrier emits intense cold from its hooves. It’s also a belligerent Pokémon—anything it wants, it takes by force.",
    "A legendary bird Pokémon that is said to appear to doomed people who are lost in icy mountains.",
    "Regice’s body was made during an ice age. The deep-frozen body can’t be melted, even by fire. This Pokémon controls frigid air of minus 328 degrees F.",
    "Its shape is similar to a robot featured in a paranormal magazine article. The robot was said to have been created by an ancient civilization.",
    "Swallowing large amounts of water, they make snow clouds inside their bodies and attack their foes with violent blizzards.",
    "It swims through icy seas while shattering ice floes with its large tusks. It is protected by its thick blubber.",
    "Its impressive tusks are made of ice. The population thinned when it turned warm after the ice age.",
    "As a protective technique, it can completely freeze its fur to make its hairs stand like needles.",
    "This Pokémon wanders around snowy, icy areas. It protects its body with powerful muscles and a thick layer of fat under its skin.",
    "It’s highly skilled at tap-dancing. It waves its cane of ice in time with its graceful movements.",
    "When its body temperature goes up, it turns into steam and vanishes. When its temperature lowers, it returns to ice.",
    "Its ice-covered body is as hard as steel. Its cumbersome frame crushes anything that stands in its way.",
    "It can make its breath freeze at will. Very able in the water, it swims around in northern seas and catches prey.",
    "Glalie has a body made of rock, which it hardens with an armor of ice. This Pokémon has the ability to freeze moisture in the atmosphere into any shape it desires.",
    "It freezes foes with an icy breath nearly -60 degrees F. What seems to be its body is actually hollow.",
    "Icy scales fall from its wings like snow as it flies over fields and mountains. The temperature of its wings is less than −290 degrees Fahrenheit.",
    "It drifted in on the flow of ocean waters from a frigid place. It keeps its head iced constantly to make sure it stays nice and cold.",
    "It seductively wiggles its hips as it walks. It can cause people to dance in unison with it.",
    "Because the long hair all over its body obscures its sight, it just keeps charging repeatedly.",
    "Sealeo has the habit of always juggling on the tip of its nose anything it sees for the first time. This Pokémon occasionally entertains itself by balancing and rolling a Spheal on its nose.",
    "Snowy mountains are this Pokémon’s habitat. During an ancient ice age, they moved to southern areas.",
    "This species left the ocean and began living on land a very long time ago. It seems to be closely related to Wailmer.",
    "It carries food all day long. There are tales about lost people who were saved by the food it had.",
    "When it is not feeling well, its mucus gets watery and the power of its Ice-type moves decreases.",
    "Its lips are the most sensitive parts on its body. It always uses its lips first to examine things.",
    "The temperature of their breath is -58° F. They create snow crystals and make snow fall in the areas around them.",
    "It blocks opponents’ attacks with the ice that shields its body. It uses cold air to repair any cracks with new ice.",
    "Snorunt live in regions with heavy snowfall. In seasons without snow, such as spring and summer, this Pokémon steals away to live quietly among stalactites and stalagmites deep in caverns.",
    "Spheal is much faster rolling than walking to get around. When groups of this Pokémon eat, they all clap at once to show their pleasure. Because of this, their mealtimes are noisy.",
    "It rubs its snout on the ground to find and dig up food. It sometimes discovers hot springs.",
    "It spits out thread imbued with a frigid sort of energy and uses it to tie its body to branches, disguising itself as an icicle while it sleeps."
]

# Replace the 'pokemon_description' column with the new list
ice_df['pokemon_description'] = new_descriptions_ice

# Now save the updated DataFrame back to the SQL database
ice_df.to_sql('ice_pokemon', con=engine, if_exists='replace', index=False)


fire_df = pd.read_sql_query("SELECT * FROM fire_pokemon", engine)

descriptions_fire = [
    "Legends claim this Pokémon flies the world's skies continuously on its magnificent seven-colored wings.",
    "It dwells in volcanic caves. It digs in with its cross-shaped feet to crawl on ceilings and walls.",
    "It lets out billows of steam and disappears into the dense fog. It’s said to live in mountains where humans do not tread.",
    "There are scant few reports of this creature being sighted. One short video shows it rampaging and spouting pillars of flame.",
    "Volcanoes erupt when it barks. Unable to restrain its extreme power, it races headlong around the land.",
    "Known as the legendary bird of fire. Every flap of its wings creates a dazzling flash of flames.",
    "This Pokémon resembles an unknown object described in a paranormal magazine as a UFO sent to observe humanity.",
    "It slithers toward people. Then, without warning, it triggers the explosion of its own head. It’s apparently one kind of Ultra Beast.",
    "A Pokémon that has been admired since the past for its beauty. It runs agilely as if on wings.",
    "It blasts fireballs of over 3,600 degrees Fahrenheit from the ends of its arms. It lives in volcanic craters.",
    "Spits fire that is hot enough to melt boulders. Known to cause forest fires unintentionally.",
    "If its rage peaks, it becomes so hot that anything that touches it will instantly go up in flames.",
    "It uses a special kind of martial arts involving all its limbs. Its fire never goes out.",
    "It gazes into the flame at the tip of its branch to achieve a focused state, which allows it to see into the future.",
    "The fiery bird changes shape when Skeledirge sings. Rumor has it that the bird was born when the fireball on Skeledirge’s head gained a soul.",
    "This Pokémon has a violent, selfish disposition. If it’s not in the mood to listen, it will ignore its Trainer’s orders with complete nonchalance.",
    "In battle, Blaziken blows out intense flames from its wrists and attacks foes courageously. The stronger the foe, the more intensely this Pokémon’s wrists burn.",
    "It juggles a pebble with its feet, turning it into a burning soccer ball. Its shots strike opponents hard and leave them scorched.",
    "It can throw a fire punch by setting its fists on fire with its fiery chin. It cares deeply about its friends.",
    "When it heats up, its body temperature reaches about 1,500 degrees Fahrenheit. It lashes its body like a whip and launches itself at enemies.",
    "Armarouge evolved through the use of a set of armor that belonged to a distinguished warrior. This Pokémon is incredibly loyal.",
    "The fiery blades on its arms burn fiercely with the lingering resentment of a sword wielder who fell before accomplishing their goal.",
    "When storing thermal energy in its body, its temperature could soar to over 1,600 degrees.",
    "The male with the largest mane of fire is the leader of the pride.",
    "Very smart and very vengeful. Grabbing one of its many tails could result in a 1,000-year curse.",
    "Very competitive, this Pokémon will chase anything that moves fast in the hopes of racing it.",
    "In the fever of an exciting battle, it showers embers from the gaps between its feathers and takes to the air.",
    "It loves sweets because they become energy for the fire burning inside its body.",
    "Its body always burns with an orange glow that enables it to hide perfectly among flames.",
    "The shell on its back is chemically unstable and explodes violently if struck. The hole in its stomach is its weak point.",
    "It breathes through a hole in its tail while it burns with an internal fire. Durant is its prey.",
    "Its internal fire burns at 2,500°F, making enough power that it can destroy a dump truck with one punch.",
    "It beats its wings together to create fire. As it moves in the steps of its beautiful dance, it bathes opponents in intense flames.",
    "You can tell how it’s feeling by the smoke spouting from its shell. Tremendous velocity is a sign of good health.",
    "Camerupt has a volcano inside its body. Magma of 18,000 degrees Fahrenheit courses through its body. Occasionally, the humps on this Pokémon’s back erupt, spewing the superheated magma.",
    "The shell on its back is just skin that has cooled and hardened. It breaks easily with a slight touch.",
    "At its throat, it bears a bell of fire. The bell rings brightly whenever this Pokémon spits fire.",
    "Its thick and fluffy fur protects it from the cold and enables it to use hotter fire moves.",
    "When its internal fire flares up, its movements grow sharper and faster. When in trouble, it emits smoke.",
    "The combination of Crocalor’s fire energy and overflowing vitality has caused an egg-shaped fireball to appear on the Pokémon’s head.",
    "Its hooves are 10 times harder than diamonds. It can trample anything completely flat in little time.",
    "It has a twig stuck in its tail. With friction from its tail fur, it sets the twig on fire and launches into battle.",
    "To intimidate attackers, it stretches the fire on its tail to make itself appear bigger.",
    "Combusken toughens up its legs and thighs by running through fields and mountains. This Pokémon’s legs possess both speed and power, enabling it to dole out ten kicks in one second.",
    "When it swings its burning tail, it elevates the temperature to unbearably high levels.",
    "Be careful if it turns its back during battle. It means that it will attack with the fire on its back.",
    "From its beak, it expels embers that set the tall grass on fire. Then it pounces on the bewildered prey that pop out of the grass.",
    "The stronger the opponent it faces, the more heat surges from its mane and the more power flows through its body.",
    "Each and every time it inhales and exhales, hot embers dribble out of its mouth and nostrils.",
    "Very protective of its territory. It will bark and bite to repel intruders from its space.",
    "While grooming itself, it builds up fur inside its stomach. It sets the fur alight and spews fiery attacks, which change based on how it coughs.",
    "When it is angered, the temperature of its head tuft reaches 600°F. It uses its tuft to roast berries.",
    "When its internal fire is burning, it cannot calm down and it runs around. When the fire diminishes, it falls asleep.",
    "It lies on warm rocks and uses the heat absorbed by its square-shaped scales to create fire energy.",
    "A warm-up of running around gets fire energy coursing through this Pokémon’s body. Once that happens, it’s ready to fight at full power.",
    "Torchic sticks with its Trainer, following behind with unsteady steps. This Pokémon breathes fire of over 1,800 degrees Fahrenheit, including fireballs that leave the foe scorched black.",
    "It agilely scales sheer cliffs to live atop craggy mountains. Its fire is put out when it sleeps.",
    "Obviously prefers hot places. When it rains, steam is said to spout from the tip of its tail.",
    "It has a timid nature. If it is startled, the flames on its back burn more vigorously.",
    "It can deftly dodge its foe’s attacks while shooting fireballs from its nose. It roasts berries before it eats them.",
    "Eating a twig fills it with energy, and its roomy ears give vent to air hotter than 390 degrees Fahrenheit.",
    "Numel is extremely dull-witted - it doesn’t notice being hit. However, it can’t stand hunger for even a second. This Pokémon’s body is a seething cauldron of boiling magma.",
    "It stores flammable gas in its body and uses it to generate heat. The yellow sections on its belly get particularly hot.",
    "At the time of birth, it has just one tail. The tail splits from its tip as it grows older.",
    "Burnt charcoal came to life and became a Pokémon. Possessing a fiery fighting spirit, Charcadet will battle even tough opponents.",
    "It never sleeps. It has to keep moving because if it stopped, its magma body would cool and harden."
]

# Replace the 'pokemon_description' column with the new list
fire_df['pokemon_description'] = descriptions_fire

# Now save the updated DataFrame back to the SQL database
fire_df.to_sql('fire_pokemon', con=engine, if_exists='replace', index=False)
# Out:
# 0                                                                                Glastrier emits intense cold from its hooves. It’s also a belligerent Pokémon—anything it wants, it takes by force.
# 1                                                                                                    A legendary bird POKéMON that is said to appear todoomed people who are lost in icy mountains.
# 2                                             REGICE’s body was made during an ice age. The deep-frozen body can’t be melted, even by fire.This POKéMON controls frigid air of minus 328 degrees F.
# 3                                                     Its shape is similar to a robot featured in a paranormal magazine article. The robot was said to have been created by an ancient civilization.
# 4                                                                         Swallowing large amounts of water, they make snow clouds inside their bodies and attack their foes with violent blizzards.
# 5                                                                                   It swims through icy seas while shattering ice floes with its large tusks. It is protected by its thick blubber.
# 6                                                                                                Its impressive tusks are made of ice. The population thinned when it turned warm after the ice age.
# 7                                                                                                  As a protective technique, it can completely freeze its fur to make its hairs stand like needles.
# 8                                                                  This Pokémon wanders around snowy, icy areas. It protects its body with powerful muscles and a thick layer of fat under its skin.
# 9                                                                                                  It’s highly skilled at tap-dancing. It waves its cane of ice in time with its graceful movements.
# 10                                                                              When its body temperature goes up, it turns into steam and vanishes. When its temperature lowers, it returns to ice.
# 11                                                                                           Its ice-covered body is as hard as steel. Its cumbersome frame crushes anything that stands in its way.
# 12                                                                                 It can make its breath freeze at will. Very able in the water, it swims around in northern seas and catches prey.
# 13                               GLALIE has a body made of rock, which it hardens with an armor of ice. This POKéMON has the ability to freezemoisture in the atmosphere into any shape it desires.
# 14                                                                                            It freezes foes with an icy breath nearly -60 degrees F. What seems to be its body is actually hollow.
# 15                                                Icy scales fall from its wings like snow as it flies over fields and mountains. The temperature of its wings is less than −290 degrees Fahrenheit.
# 16                                                             It drifted in on the flow of ocean waters from a frigid place. It keeps its head iced constantly to make sure it stays nice and cold.
# 17                                                                                                      It seductively wiggles its hips as it walks. Itcan cause people to dance in unison with it.
# 18                                                                                                    Because the long hair all over its body obscures itssight, it just keeps charging repeatedly.
# 19    SEALEO has the habit of always juggling on the tip of its nose anything it sees for the first time.This POKéMON occasionally entertains itself by balancing and rolling a SPHEAL on its nose.
# 20                                                                                              Snowy mountains are this Pokémon’s habitat. During an ancient ice age, they moved to southern areas.
# 21                                                                             This species left the ocean and began living on land a very long time ago. It seems to be closely related to Wailmer.
# 22                                                                                                It carries food all day long. There are talesabout lost people who were saved by the food it had.
# 23                                                                                                 When it is not feeling well, its mucus gets watery and the power of its Ice-type moves decreases.
# 24                                                                                               Its lips are the most sensitive parts on its body.It always uses its lips first to examine things.
# 25                                                                                 The temperature of their breath is -58° F. They create snow crystals and make snow fall in the areas around them.
# 26                                                                              It blocks opponents’ attacks with the ice that shields its body. It uses cold air to repair any cracks with new ice.
# 27      SNORUNT live in regions with heavy snowfall. In seasons without snow, such as spring and summer, this POKéMONsteals away to live quietly among stalactites and stalagmites deep in caverns.
# 28             SPHEAL is much faster rolling than  walking to get around. When groups of this POKéMON eat, they all clap at onceto show their pleasure. Because of this, their mealtimes are noisy.
# 29                                                                                                      It rubs its snout on the ground to find and dig upfood. It sometimes discovers hot springs.
# 30                                                  It spits out thread imbued with a frigid sort of energy and uses it to tie its body to branches, disguising itself as an icicle while it sleeps.
# Name: pokemon_description, dtype: object
# 66
