# %%
import os
import json
import requests
import pandas as pd

# %%
request_url = 'https://pokeapi.co/api/v2/generation/1'
response = requests.get(request_url)
response_1 = response.json()
with open ('../generation_1.json', 'w') as file: 
    json.dump(response_1,file)

gen_1_poke_df = pd.json_normalize(response_1, record_path = 'pokemon_species')
display(gen_1_poke_df)
# Out:
#            name                                             url
# 0     bulbasaur    https://pokeapi.co/api/v2/pokemon-species/1/
# 1    charmander    https://pokeapi.co/api/v2/pokemon-species/4/
# 2      squirtle    https://pokeapi.co/api/v2/pokemon-species/7/
# 3      caterpie   https://pokeapi.co/api/v2/pokemon-species/10/
# 4        weedle   https://pokeapi.co/api/v2/pokemon-species/13/
# ..          ...                                             ...
# 146     omastar  https://pokeapi.co/api/v2/pokemon-species/139/
# 147    kabutops  https://pokeapi.co/api/v2/pokemon-species/141/
# 148     snorlax  https://pokeapi.co/api/v2/pokemon-species/143/
# 149   dragonair  https://pokeapi.co/api/v2/pokemon-species/148/
# 150   dragonite  https://pokeapi.co/api/v2/pokemon-species/149/
#
# [151 rows x 2 columns]

# %%
def extract_pokemon_id(url): 
    id = url.rstrip('/').split('/')[-1]
    return id

# %%
gen_1_poke_df['pokemon_id'] = gen_1_poke_df['url'].apply(extract_pokemon_id)
display(gen_1_poke_df)
gen_1_poke_df = gen_1_poke_df.sort_values('pokemon_id')
# Out:
#            name                                             url pokemon_id
# 0     bulbasaur    https://pokeapi.co/api/v2/pokemon-species/1/          1
# 1    charmander    https://pokeapi.co/api/v2/pokemon-species/4/          4
# 2      squirtle    https://pokeapi.co/api/v2/pokemon-species/7/          7
# 3      caterpie   https://pokeapi.co/api/v2/pokemon-species/10/         10
# 4        weedle   https://pokeapi.co/api/v2/pokemon-species/13/         13
# ..          ...                                             ...        ...
# 146     omastar  https://pokeapi.co/api/v2/pokemon-species/139/        139
# 147    kabutops  https://pokeapi.co/api/v2/pokemon-species/141/        141
# 148     snorlax  https://pokeapi.co/api/v2/pokemon-species/143/        143
# 149   dragonair  https://pokeapi.co/api/v2/pokemon-species/148/        148
# 150   dragonite  https://pokeapi.co/api/v2/pokemon-species/149/        149
#
# [151 rows x 3 columns]

# %%
# THIS FUNCTION IS VERY INEFFICIENT - THIS VERSION IS FOR TESTING ONLY
def get_pokemon_species_details(pokemon_id): 
    request_url = f'https://pokeapi.co/api/v2/pokemon-species/{pokemon_id}'
    response = requests.get(request_url)
    data = response.json()
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        print(f"Response content: {response.text}")
    else:
        with open(f'../data/generation_1_pokemon_details/{pokemon_id}_species_details', 'w') as file:
            json.dump(data, file)
            species_details_df = pd.json_normalize(data)
    return species_details_df

get_pokemon_species_details(1)
# Out:
#    base_happiness  capture_rate  \
# 0              50            45
#
#                                           egg_groups evolves_from_species  \
# 0  [{'name': 'monster', 'url': 'https://pokeapi.c...                 None
#
#                                  flavor_text_entries form_descriptions  \
# 0  [{'flavor_text': 'A strange seed was
# planted o...                []
#
#    forms_switchable  gender_rate  \
# 0             False            1
#
#                                               genera  has_gender_differences  \
# 0  [{'genus': 'たねポケモン', 'language': {'name': 'ja-...                   False
#
#    ...                                   color.url  \
# 0  ...  https://pokeapi.co/api/v2/pokemon-color/5/
#
#                             evolution_chain.url  generation.name  \
# 0  https://pokeapi.co/api/v2/evolution-chain/1/     generation-i
#
#                             generation.url  growth_rate.name  \
# 0  https://pokeapi.co/api/v2/generation/1/       medium-slow
#
#                             growth_rate.url habitat.name  \
# 0  https://pokeapi.co/api/v2/growth-rate/4/    grassland
#
#                                     habitat.url shape.name  \
# 0  https://pokeapi.co/api/v2/pokemon-habitat/3/  quadruped
#
#                                     shape.url
# 0  https://pokeapi.co/api/v2/pokemon-shape/8/
#
# [1 rows x 32 columns]

# %%
def get_pokemon_species_type(pokemon_id): 
    request_url = f'https://pokeapi.co/api/v2/type/{pokemon_id}'
    response = requests.get(request_url)
    data = response.json()
    if response.status_code != 200:
        print(f"Error: Received status code {response.status_code}")
        print(f"Response content: {response.text}")
    else:
        with open(f'../data/generation_1_pokemon_type_details/{pokemon_id}_type_details', 'w') as file:
            json.dump(data, file)
            species_type_df = pd.json_normalize(data)
    return species_type_df

get_pokemon_species_type(1)
# Out:
#                                         game_indices  id  \
# 0  [{'game_index': 0, 'generation': {'name': 'gen...   1
#
#                                                moves    name  \
# 0  [{'name': 'pound', 'url': 'https://pokeapi.co/...  normal
#
#                                                names past_damage_relations  \
# 0  [{'language': {'name': 'ja-Hrkt', 'url': 'http...                    []
#
#                                              pokemon  \
# 0  [{'pokemon': {'name': 'pidgey', 'url': 'https:...
#
#                  damage_relations.double_damage_from  \
# 0  [{'name': 'fighting', 'url': 'https://pokeapi....
#
#   damage_relations.double_damage_to damage_relations.half_damage_from  ...  \
# 0                                []                                []  ...
#
#       sprites.generation-v.black-2-white-2.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#           sprites.generation-v.black-white.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.generation-vi.omega-ruby-alpha-sapphire.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#                  sprites.generation-vi.x-y.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.generation-vii.lets-go-pikachu-lets-go-eevee.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#            sprites.generation-vii.sun-moon.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.generation-vii.ultra-sun-ultra-moon.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#   sprites.generation-viii.brilliant-diamond-and-shining-pearl.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#     sprites.generation-viii.legends-arceus.name_icon  \
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
#       sprites.generation-viii.sword-shield.name_icon
# 0  https://raw.githubusercontent.com/PokeAPI/spri...
#
# [1 rows x 36 columns]

# %%
list_of_species_details_df = gen_1_poke_df['pokemon_id'].apply(get_pokemon_species_details)
species_details_df = pd.concat(list_of_species_details_df.to_list(), ignore_index=True)

list_of_species_type_df = gen_1_poke_df['pokemon_id'].apply(get_pokemon_species_type)
species_type_df = pd.concat(list_of_species_type_df.to_list(), ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File c:\Users\chang\Anaconda\Lib\site-packages\requests\models.py:974, in Response.json(self, **kwargs)
#     973 try:
# --> 974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File c:\Users\chang\Anaconda\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#
# File c:\Users\chang\Anaconda\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     333 """Return the Python representation of ``s`` (a ``str`` instance
#     334 containing a JSON document).
#     335
#     336 """
# --> 337 obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338 end = _w(s, end).end()
#
# File c:\Users\chang\Anaconda\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[44], line 4
#       1 list_of_species_details_df = gen_1_poke_df['pokemon_id'].apply(get_pokemon_species_details)
#       2 species_details_df = pd.concat(list_of_species_details_df.to_list(), ignore_index=True)
# ----> 4 list_of_species_type_df = gen_1_poke_df['pokemon_id'].apply(get_pokemon_species_type)
#       5 species_type_df = pd.concat(list_of_species_type_df.to_list(), ignore_index=True)
#
# File c:\Users\chang\Anaconda\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\chang\Anaconda\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\chang\Anaconda\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\chang\Anaconda\Lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\chang\Anaconda\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[41], line 4, in get_pokemon_species_type(pokemon_id)
#       2 request_url = f'https://pokeapi.co/api/v2/type/{pokemon_id}'
#       3 response = requests.get(request_url)
# ----> 4 data = response.json()
#       5 if response.status_code != 200:
#       6     print(f"Error: Received status code {response.status_code}")
#
# File c:\Users\chang\Anaconda\Lib\site-packages\requests\models.py:978, in Response.json(self, **kwargs)
#     974     return complexjson.loads(self.text, **kwargs)
#     975 except JSONDecodeError as e:
#     976     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     977     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 978     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
species_details_df['habitat.name'].value_counts()
# Out:
# habitat.name
# grassland        35
# urban            22
# forest           21
# waters-edge      19
# mountain         18
# sea              15
# rough-terrain     8
# cave              8
# rare              5
# Name: count, dtype: int64
